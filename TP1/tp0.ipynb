# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print(pd.__version__)
# to print the full output
# Out:
# 2.1.3

# %% [markdown]
# ## Partie 1 : Data exploration

# %%
df = pd.read_csv("dataset\datasetCovid.csv")

# %%
df.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
df.tail()
# Out:
#            Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 5639  ae66feb9e4dc3a0                     3               positive
# 5640  517c2834024f3ea                    17               negative
# 5641  5c57d6037fe266d                     4               negative
# 5642  c20c44766f28291                    10               negative
# 5643  2697fdccbfeb7f7                    19               positive
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 5639                                               0
# 5640                                               0
# 5641                                               0
# 5642                                               0
# 5643                                               0
#
#       Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 5639                                                  0
# 5640                                                  0
# 5641                                                  0
# ...

# %%
print("The target varible is: ", df["SARS-Cov-2 exam result"])
# Out:
# The target varible is:  0       negative
# 1       negative
# 2       negative
# 3       negative
# 4       negative
#           ...
# 5639    positive
# 5640    negative
# 5641    negative
# 5642    negative
# 5643    positive
# Name: SARS-Cov-2 exam result, Length: 5644, dtype: object

# %%
len(df.columns)
# Out:
# 111

# %%
print("The number of rows is: ", df.shape[0])
print("The number of columns is: ", df.shape[1])
# Out:
# The number of rows is:  5644
# The number of columns is:  111

# %%
print(df.dtypes)
# Out:
# Patient ID                                                object
# Patient age quantile                                       int64
# SARS-Cov-2 exam result                                    object
# Patient addmited to regular ward (1=yes, 0=no)             int64
# Patient addmited to semi-intensive unit (1=yes, 0=no)      int64
#                                                           ...
# HCO3 (arterial blood gas analysis)                       float64
# pO2 (arterial blood gas analysis)                        float64
# Arteiral Fio2                                            float64
# Phosphor                                                 float64
# ctO2 (arterial blood gas analysis)                       float64
# Length: 111, dtype: object

# %%
# count the number of columns of each type
print(df.dtypes.value_counts())
# Out:
# float64    70
# object     37
# int64       4
# Name: count, dtype: int64

# %%
df.dtypes.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
print(df.isnull().sum())
# Out:
# Patient ID                                                  0
# Patient age quantile                                        0
# SARS-Cov-2 exam result                                      0
# Patient addmited to regular ward (1=yes, 0=no)              0
# Patient addmited to semi-intensive unit (1=yes, 0=no)       0
#                                                          ...
# HCO3 (arterial blood gas analysis)                       5617
# pO2 (arterial blood gas analysis)                        5617
# Arteiral Fio2                                            5624
# Phosphor                                                 5624
# ctO2 (arterial blood gas analysis)                       5617
# Length: 111, dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
(df.isnull().sum() / df.shape[0]).sort_values(ascending=True)
# Out:
# Patient ID                                               0.0
# Patient age quantile                                     0.0
# SARS-Cov-2 exam result                                   0.0
# Patient addmited to regular ward (1=yes, 0=no)           0.0
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.0
#                                                         ...
# Partial thromboplastin time�(PTT)�                       1.0
# Urine - Sugar                                            1.0
# Mycoplasma pneumoniae                                    1.0
# D-Dimer                                                  1.0
# Prothrombin time (PT), Activity                          1.0
# Length: 111, dtype: float64

# %%
missing_rate = df.isnull().sum() / df.shape[0]
round(missing_rate, 4)
# Out:
# Patient ID                                               0.0000
# Patient age quantile                                     0.0000
# SARS-Cov-2 exam result                                   0.0000
# Patient addmited to regular ward (1=yes, 0=no)           0.0000
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.0000
#                                                           ...
# HCO3 (arterial blood gas analysis)                       0.9952
# pO2 (arterial blood gas analysis)                        0.9952
# Arteiral Fio2                                            0.9965
# Phosphor                                                 0.9965
# ctO2 (arterial blood gas analysis)                       0.9952
# Length: 111, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x="SARS-Cov-2 exam result", data=df, palette="Set2")
plt.xlabel("Patient ID")
plt.ylabel("SARS-Cov-2 exam result")
plt.title("Histogram of Patient ID vs SARS-Cov-2 exam result")
plt.show()
# Out:
# C:\Users\PC CABA DZ\AppData\Local\Temp\ipykernel_18260\3943944452.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="SARS-Cov-2 exam result", data=df, palette="Set2")

# %%
less_than_90_percent = df.isna().sum() / df.shape[0] < 0.9
less_than_90_percent
# Out:
# Patient ID                                                True
# Patient age quantile                                      True
# SARS-Cov-2 exam result                                    True
# Patient addmited to regular ward (1=yes, 0=no)            True
# Patient addmited to semi-intensive unit (1=yes, 0=no)     True
#                                                          ...
# HCO3 (arterial blood gas analysis)                       False
# pO2 (arterial blood gas analysis)                        False
# Arteiral Fio2                                            False
# Phosphor                                                 False
# ctO2 (arterial blood gas analysis)                       False
# Length: 111, dtype: bool

# %%
# df[df.columns[df.isna().sum()/df.shape[0]<0.9]]
# df=df[df.columns[df.isna().sum()/df.shape[0]<0.9]]
# df

# %%
df.describe()
# Out:
#        Patient age quantile  Patient addmited to regular ward (1=yes, 0=no)  \
# count           5644.000000                                     5644.000000
# mean               9.318391                                        0.013997
# std                5.777903                                        0.117489
# min                0.000000                                        0.000000
# 25%                4.000000                                        0.000000
# 50%                9.000000                                        0.000000
# 75%               14.000000                                        0.000000
# max               19.000000                                        1.000000
#
#        Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# count                                        5644.000000
# mean                                            0.008859
# std                                             0.093713
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(
    pd.crosstab(
        df["Patient age quantile"], df["SARS-Cov-2 exam result"], normalize="index"
    ),
    annot=True,
    cmap="Blues",
)
plt.title(f"Correlation between Patient age quantile and SARS-Cov-2 exam result")
plt.xlabel("SARS-Cov-2 exam result")
plt.ylabel("Patient age quantile")
plt.show()

# %% [markdown]
# ## Partie 2 : Prétraitement des données

# %%
new_cols = [
    "Patient age quantile",
    "SARS-Cov-2 exam result",
    "Patient addmited to regular ward (1=yes, 0=no)",
    "Patient addmited to semi-intensive unit (1=yes, 0=no)",
    "Patient addmited to intensive care unit (1=yes, 0=no)",
]
pruned_df = df[new_cols]

# %%
pruned_df.isnull().sum()
# Out:
# Patient age quantile                                     0
# SARS-Cov-2 exam result                                   0
# Patient addmited to regular ward (1=yes, 0=no)           0
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0
# Patient addmited to intensive care unit (1=yes, 0=no)    0
# dtype: int64

# %%
pruned_df.dtypes
# Out:
# Patient age quantile                                      int64
# SARS-Cov-2 exam result                                   object
# Patient addmited to regular ward (1=yes, 0=no)            int64
# Patient addmited to semi-intensive unit (1=yes, 0=no)     int64
# Patient addmited to intensive care unit (1=yes, 0=no)     int64
# dtype: object

# %%
pruned_df.shape
# Out:
# (5644, 5)

# %%
pruned_df.is
# Out:
#   Cell In[68], line 1
#     pruned_df.is
#               ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(pruned_df.isna(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# We can notice that thr patient ID and sars cov 2 results are string objects and hence we need to convert them to float type in order to get the heatmap

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
pruned_df["SARS-Cov-2 exam result"] = le.fit_transform(
    pruned_df["SARS-Cov-2 exam result"]
)
# Out:
# C:\Users\PC CABA DZ\AppData\Local\Temp\ipykernel_18260\2834030670.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pruned_df["SARS-Cov-2 exam result"] = le.fit_transform(

# %%
pruned_df
# Out:
#       Patient age quantile  SARS-Cov-2 exam result  \
# 0                       13                       0
# 1                       17                       0
# 2                        8                       0
# 3                        5                       0
# 4                       15                       0
# ...                    ...                     ...
# 5639                     3                       1
# 5640                    17                       0
# 5641                     4                       0
# 5642                    10                       0
# 5643                    19                       1
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...

# %%
corr_matrix = pruned_df.corr()
plt.figure(figsize=(7, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation matrix of the dataset")
plt.show()

# %% [markdown]
# After analyzing the above heatmap, we can conclude that the `Patient addmited to regular ward` variable is the most correlated to our target variable `SARS-Cov-2 exam result`

# %%
SAVE_PROCESSED_DF: bool = False
if SAVE_PROCESSED_DF:
    pruned_df.to_csv("processed_covid_df.csv", index=False)

# %%
pruned_df.columns
# Out:
# Index(['Patient age quantile', 'SARS-Cov-2 exam result',
#        'Patient addmited to regular ward (1=yes, 0=no)',
#        'Patient addmited to semi-intensive unit (1=yes, 0=no)',
#        'Patient addmited to intensive care unit (1=yes, 0=no)'],
#       dtype='object')

# %% [markdown]
# ## Partie 2 : Prétraitement des données

# %% [markdown]
# There are different classification algortihms that we can use in order to predict whether a patient tested positive or negative to Covid 19, let's try the following algortihms :
# - Logistic regression from scikit-learn
# - KNN from scikit-learn also
# - Neural netwroks built with Pytorch (`Optional`)

# %% [markdown]
# ## 1. Logistic regressor classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
pruned_df.columns
# Out:
# Index(['Patient age quantile', 'SARS-Cov-2 exam result',
#        'Patient addmited to regular ward (1=yes, 0=no)',
#        'Patient addmited to semi-intensive unit (1=yes, 0=no)',
#        'Patient addmited to intensive care unit (1=yes, 0=no)'],
#       dtype='object')

# %%
X = pruned_df[
    [
        "Patient age quantile",
        "Patient addmited to regular ward (1=yes, 0=no)",
        "Patient addmited to semi-intensive unit (1=yes, 0=no)",
        "Patient addmited to intensive care unit (1=yes, 0=no)",
    ]
]
y = pruned_df["SARS-Cov-2 exam result"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9016829052258636

# %%
from sklearn.model_selection import learning_curve
import numpy as np

train_sizes, train_scores, test_scores = learning_curve(
    model,
    X_train,
    y_train,
    cv=5,
    scoring="accuracy",
    train_sizes=np.linspace(0.1, 1.0, 10),
)

# %%
# Calculate mean and standard deviation of training and test scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# %%
# Plot learning curve
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, label="Training Accuracy", marker="o")
plt.fill_between(
    train_sizes,
    train_mean - train_std,
    train_mean + train_std,
    alpha=0.15,
    color="blue",
)
plt.plot(train_sizes, test_mean, label="Validation Accuracy", marker="o")
plt.fill_between(
    train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.15, color="green"
)

plt.title("Learning Curve")
plt.xlabel("Training Examples")
plt.ylabel("Accuracy")
plt.legend(loc="upper right")
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
)

class_report = classification_report(y_test, y_pred)
print(f"Classification Report:\n{class_report}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      1018
#            1       0.00      0.00      0.00       111
#
#     accuracy                           0.90      1129
#    macro avg       0.45      0.50      0.47      1129
# weighted avg       0.81      0.90      0.86      1129
# C:\Users\PC CABA DZ\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\PC CABA DZ\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ### 2. K- Nearest Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Create a KNN model with a specified number of neighbors
model2 = KNeighborsClassifier(n_neighbors=k)

# Fit the model to the training data
model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Create a KNN model with a specified number of neighbors
# ----> 2 model2 = KNeighborsClassifier(n_neighbors=k)
#       4 # Fit the model to the training data
#       5 model2.fit(X_train, y_train)
#
# NameError: name 'k' is not defined

# %%
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9034543844109831

# %%
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
)

class_report = classification_report(y_test, y_pred)
print(f"Classification Report:\n{class_report}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      1018
#            1       0.75      0.03      0.05       111
#
#     accuracy                           0.90      1129
#    macro avg       0.83      0.51      0.50      1129
# weighted avg       0.89      0.90      0.86      1129
